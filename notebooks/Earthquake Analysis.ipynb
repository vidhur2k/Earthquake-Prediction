# %% [markdown]
# Link to competition: https://www.drivendata.org/competitions/57/nepal-earthquake/page/136/
# <iframe src=”https://www.drivendata.org/competitions/57/nepal-earthquake/page/136/></iframe>

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("../data/train_values.csv")
test = pd.read_csv("../data/test_values.csv")
train.drop('building_id', axis=1, inplace=True)
train.head(10)
# Out:
#    geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  age  \
# 0               6             487           12198                    2   30
# 1               8             900            2812                    2   10
# 2              21             363            8973                    2   10
# 3              22             418           10694                    2   10
# 4              11             131            1488                    3   30
# 5               8             558            6089                    2   10
# 6               9             475           12066                    2   25
# 7              20             323           12236                    2    0
# 8               0             757            7219                    2   15
# 9              26             886             994                    1    0
#
#    area_percentage  height_percentage land_surface_condition foundation_type  \
# ...

# %%
test.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       300051              17             596           11307
# 1        99355               6             141           11987
# 2       890251              22              19           10044
# 3       745817              26              39             633
# 4       421793              17             289            7970
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    3   20                7                  6
# 1                    2   25               13                  5
# 2                    2    5                4                  5
# 3                    1    0               19                  3
# 4                    3   15                8                  7
#
#   land_surface_condition foundation_type  ... has_secondary_use_agriculture  \
# 0                      t               r  ...                             0
# ...

# %%
fig, ax = plt.subplots(figsize=(20,20)) 
sn.heatmap(train.corr())
